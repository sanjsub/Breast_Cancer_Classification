# %%
import pandas as pd

# %%
train = pd.read_csv('DBT_train.csv')
train.head()
# Out:
#     PatientID    StudyUID  Label  View  \
# 0  DBT-P01013  DBT-S00665      0   lcc
# 1  DBT-P01013  DBT-S00665      0  lmlo
# 2  DBT-P01013  DBT-S00665      0   rcc
# 3  DBT-P01013  DBT-S00665      0  rmlo
# 4  DBT-P04493  DBT-S02147      0   lcc
#
#                                     descriptive_path  \
# 0  Breast-Cancer-Screening-DBT/DBT-P01013/01-01-2...
# 1  Breast-Cancer-Screening-DBT/DBT-P01013/01-01-2...
# 2  Breast-Cancer-Screening-DBT/DBT-P01013/01-01-2...
# 3  Breast-Cancer-Screening-DBT/DBT-P01013/01-01-2...
# 4  Breast-Cancer-Screening-DBT/DBT-P04493/01-01-2...
#
#                                         classic_path
# 0  Breast-Cancer-Screening-DBT/DBT-P01013/1.2.826...
# 1  Breast-Cancer-Screening-DBT/DBT-P01013/1.2.826...
# 2  Breast-Cancer-Screening-DBT/DBT-P01013/1.2.826...
# 3  Breast-Cancer-Screening-DBT/DBT-P01013/1.2.826...
# 4  Breast-Cancer-Screening-DBT/DBT-P04493/1.2.826...

# %%
train['descriptive_path'].iloc[0]
# Out:
# 'Breast-Cancer-Screening-DBT/DBT-P01013/01-01-2000-DBT-S00665-MAMMO screening digital bilateral-75731/4658.000000-67738/1-1.dcm'

# %%
for i in range(len(train)):
    path = train['descriptive_path'].iloc[i]
    new_path = 'tiff_' + path[:-13] + 'NA-' + path[-13:-3] + 'tiff'
    train['descriptive_path'].iloc[i] = new_path
train
# Out:
# C:\Users\Poey\Anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#         PatientID    StudyUID  Label  View  \
# 0      DBT-P01013  DBT-S00665      0   lcc
# 1      DBT-P01013  DBT-S00665      0  lmlo
# 2      DBT-P01013  DBT-S00665      0   rcc
# 3      DBT-P01013  DBT-S00665      0  rmlo
# 4      DBT-P04493  DBT-S02147      0   lcc
# ...           ...         ...    ...   ...
# 13255  DBT-P01154  DBT-S04977      0  rmlo
# 13256  DBT-P01460  DBT-S04074      0   lcc
# 13257  DBT-P01460  DBT-S04074      0  lmlo
# 13258  DBT-P01460  DBT-S04074      0   rcc
# 13259  DBT-P01460  DBT-S04074      0  rmlo
#
#                                         descriptive_path  \
# ...

# %%
train['descriptive_path'].iloc[1000]
# Out:
# 'tiff_Breast-Cancer-Screening-DBT/DBT-P00054/01-01-2000-DBT-S00412-MAMMO screening digital bilateral-47074/1469.000000-NA-40708/1-1.tiff'

# %%
val = pd.read_csv('DBT_val.csv')
val
# Out:
#        PatientID    StudyUID  Label  View  \
# 0     DBT-P02642  DBT-S01298      0   lcc
# 1     DBT-P02642  DBT-S01298      0  lmlo
# 2     DBT-P02642  DBT-S01298      0   rcc
# 3     DBT-P02642  DBT-S01298      0  rmlo
# 4     DBT-P03849  DBT-S00732      0   lcc
# ...          ...         ...    ...   ...
# 1891  DBT-P04964  DBT-S03336      0  rmlo
# 1892  DBT-P02859  DBT-S00209      0   lcc
# 1893  DBT-P02859  DBT-S00209      0  lmlo
# 1894  DBT-P02859  DBT-S00209      0   rcc
# 1895  DBT-P02859  DBT-S00209      0  rmlo
#
#                                        descriptive_path  \
# 0     Breast-Cancer-Screening-DBT/DBT-P02642/01-01-2...
# 1     Breast-Cancer-Screening-DBT/DBT-P02642/01-01-2...
# 2     Breast-Cancer-Screening-DBT/DBT-P02642/01-01-2...
# 3     Breast-Cancer-Screening-DBT/DBT-P02642/01-01-2...
# 4     Breast-Cancer-Screening-DBT/DBT-P03849/01-01-2...
# ...                                                 ...
# 1891  Breast-Cancer-Screening-DBT/DBT-P04964/01-01-2...
# ...

# %%
for i in range(len(val)):
    path = val['descriptive_path'].iloc[i]
    new_path = 'tiff_' + path[:-13] + 'NA-' + path[-13:-3] + 'tiff'
    val['descriptive_path'].iloc[i] = new_path
val
# Out:
# C:\Users\Poey\Anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#        PatientID    StudyUID  Label  View  \
# 0     DBT-P02642  DBT-S01298      0   lcc
# 1     DBT-P02642  DBT-S01298      0  lmlo
# 2     DBT-P02642  DBT-S01298      0   rcc
# 3     DBT-P02642  DBT-S01298      0  rmlo
# 4     DBT-P03849  DBT-S00732      0   lcc
# ...          ...         ...    ...   ...
# 1891  DBT-P04964  DBT-S03336      0  rmlo
# 1892  DBT-P02859  DBT-S00209      0   lcc
# 1893  DBT-P02859  DBT-S00209      0  lmlo
# 1894  DBT-P02859  DBT-S00209      0   rcc
# 1895  DBT-P02859  DBT-S00209      0  rmlo
#
#                                        descriptive_path  \
# ...

# %%
val['descriptive_path'].iloc[1000]
# Out:
# 'tiff_Breast-Cancer-Screening-DBT/DBT-P02507/01-01-2000-DBT-S03697-MAMMO SCREENING DIGITAL BILATERAL-91629/2364.000000-NA-96714/1-1.tiff'

# %%
test = pd.read_csv('DBT_test.csv')
test
# Out:
#        PatientID    StudyUID  Label  View  \
# 0     DBT-P00419  DBT-S00183      0   lcc
# 1     DBT-P00419  DBT-S00183      0  lmlo
# 2     DBT-P00419  DBT-S00183      0   rcc
# 3     DBT-P00419  DBT-S00183      0  rmlo
# 4     DBT-P00525  DBT-S03064      0   lcc
# ...          ...         ...    ...   ...
# 3787  DBT-P02879  DBT-S04024      0  rmlo
# 3788  DBT-P05024  DBT-S00990      0   lcc
# 3789  DBT-P05024  DBT-S00990      0  lmlo
# 3790  DBT-P05024  DBT-S00990      0   rcc
# 3791  DBT-P05024  DBT-S00990      0  rmlo
#
#                                        descriptive_path  \
# 0     Breast-Cancer-Screening-DBT/DBT-P00419/01-01-2...
# 1     Breast-Cancer-Screening-DBT/DBT-P00419/01-01-2...
# 2     Breast-Cancer-Screening-DBT/DBT-P00419/01-01-2...
# 3     Breast-Cancer-Screening-DBT/DBT-P00419/01-01-2...
# 4     Breast-Cancer-Screening-DBT/DBT-P00525/01-01-2...
# ...                                                 ...
# 3787  Breast-Cancer-Screening-DBT/DBT-P02879/01-01-2...
# ...

# %%
for i in range(len(test)):
    path = test['descriptive_path'].iloc[i]
    new_path = 'tiff_'  + path[:-13] + 'NA-' + path[-13:-3] + 'tiff'
    test['descriptive_path'].iloc[i] = new_path
test
# Out:
# C:\Users\Poey\Anaconda3\lib\site-packages\pandas\core\indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
#        PatientID    StudyUID  Label  View  \
# 0     DBT-P00419  DBT-S00183      0   lcc
# 1     DBT-P00419  DBT-S00183      0  lmlo
# 2     DBT-P00419  DBT-S00183      0   rcc
# 3     DBT-P00419  DBT-S00183      0  rmlo
# 4     DBT-P00525  DBT-S03064      0   lcc
# ...          ...         ...    ...   ...
# 3787  DBT-P02879  DBT-S04024      0  rmlo
# 3788  DBT-P05024  DBT-S00990      0   lcc
# 3789  DBT-P05024  DBT-S00990      0  lmlo
# 3790  DBT-P05024  DBT-S00990      0   rcc
# 3791  DBT-P05024  DBT-S00990      0  rmlo
#
#                                        descriptive_path  \
# ...

# %%
test['descriptive_path'].iloc[1000]
# Out:
# 'tiff_Breast-Cancer-Screening-DBT/DBT-P03875/01-01-2000-DBT-S01175-MAMMO screening digital bilateral-86323/19731.000000-NA-39008/1-1.tiff'

# %%
train.to_csv('DBT_train_tiff.csv', index=False)
val.to_csv('DBT_val_tiff.csv', index=False)
test.to_csv('DBT_test_tiff.csv', index=False)
